# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">Visualización de Datos</p>
# <p style="margin: 0; text-align:right;">Máster Universitario de Ciencia de datos </p>
# <p style="margin: 0; text-align:right;">Universitat Oberta de Catalunya</p>
#     <p style="margin: 0; text-align:right; padding-button: 100px;">Autor: Jorge Alonso Hernández</p>
# </div>
# </div>
# <div style="width:100%;">&nbsp;</div>
#
#
# # PEC2: Estudio de técnicas de visualización de datos

# %%
# Carga de librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
data = pd.read_excel('6-2-incidencia-acumulada-la-rioja.xlsx')
print(data)
# Out:
#          FECHA  NUEVOS CASOS  ACUMULADOS 14 DIAS  IA 14 DIAS  \
# 0   2022-11-20           8.0               223.0   69.731954
# 1   2022-11-19           8.0               218.0   68.168457
# 2   2022-11-18          19.0               213.0   66.604961
# 3   2022-11-17          23.0               215.0   67.230359
# 4   2022-11-16          12.0               217.0   67.855758
# ..         ...           ...                 ...         ...
# 684 2021-01-05         177.0              1226.0  383.227993
# 685 2021-01-04          84.0              1118.0  349.468920
# 686 2021-01-03          89.0              1061.0  331.651631
# 687 2021-01-02          46.0              1001.0  312.896591
# 688 2021-01-01          78.0              1042.0  325.712535
#
#      ACUMULADOS 7 DIAS   IA 7 DIAS
# 0                134.0   41.901712
# 1                133.0   41.589013
# 2                126.0   39.400118
# 3                118.0   36.898523
# 4                110.0   34.396928
# ...

# %%
print(data['NUEVOS CASOS'])
# Out:
# 0        8.0
# 1        8.0
# 2       19.0
# 3       23.0
# 4       12.0
#        ...
# 684    177.0
# 685     84.0
# 686     89.0
# 687     46.0
# 688     78.0
# Name: NUEVOS CASOS, Length: 689, dtype: float64

# %%
plt.plot(data.FECHA, data['NUEVOS CASOS'])
plt.title('CASOS DE COVID19')
plt.xlabel('x_axis name')
plt.ylabel('y_axis name')
plt.show()

# %%
data_corr = data[['NUEVOS CASOS','ACUMULADOS 7 DIAS','IA 7 DIAS']]
corr_df = data_corr.corr(method='pearson')

plt.figure(figsize=(8, 6))
sns.heatmap(corr_df, annot=True)
plt.show()

# %%
corr_df = data_corr.corr(method='pearson')

plt.matshow(corr_df, 2)
plt.show()

# %%
fig = go.Figure(data=go.Ohlc(x=data['FECHA'],
                open=data['IA 7 DIAS'],
                high=data['ACUMULADOS 14 DIAS'],
                low=data['ACUMULADOS 7 DIAS'],
                close=data['IA 14 DIAS']))
fig.show()
# Out:
# <div>                            <div id="663a67f4-3f67-4550-a277-d43dbef9bf1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("663a67f4-3f67-4550-a277-d43dbef9bf1b")) {                    Plotly.newPlot(                        "663a67f4-3f67-4550-a277-d43dbef9bf1b",                        [{"close":[69.731954120752,68.1684573915871,66.6049606624223,67.2303593540882,67.8557580457542,70.0446534665849,62.5398691665937,57.8493789790992,56.2858822499343,57.8493789790992,61.9144704749278,65.3541632790904,67.2303593540882,66.2922613165893,67.8557580457542,68.1684573915871,69.731954120752,71.6081501957498,73.7970456165806,76.9240390749103,90.9955096373938,94.4352024415565,96.3113985165543,97.8748952457191,101.627287395715,102.878084779047,97.2494965540532,
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')

# %%
df.head()
# Out:
#          Date   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0  2015-02-17  127.489998  128.880005  126.919998  127.830002     63152400
# 1  2015-02-18  127.629997  128.779999  127.449997  128.720001     44891700
# 2  2015-02-19  128.479996  129.029999  128.330002  128.449997     37362400
# 3  2015-02-20  128.619995  129.500000  128.050003  129.500000     48948400
# 4  2015-02-23  130.020004  133.000000  129.660004  133.000000     70974100
#
#    AAPL.Adjusted          dn        mavg          up   direction
# 0     122.905254  106.741052  117.927667  129.114281  Increasing
# 1     123.760965  107.842423  118.940333  130.038244  Increasing
# 2     123.501363  108.894245  119.889167  130.884089  Decreasing
# 3     124.510914  109.785449  120.763500  131.741551  Increasing
# 4     127.876074  110.372516  121.720167  133.067817  Increasing

# %%
fig = go.Figure(data=go.Ohlc(x=df['Date'],
                    open=df['AAPL.Open'],
                    high=df['AAPL.High'],
                    low=df['AAPL.Low'],
                    close=df['AAPL.Close']))
fig.show()
# Out:
# <div>                            <div id="a45c812d-2d17-43e2-9c43-78a5b4667edf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a45c812d-2d17-43e2-9c43-78a5b4667edf")) {                    Plotly.newPlot(                        "a45c812d-2d17-43e2-9c43-78a5b4667edf",                        [{"close":[127.830002,128.720001,128.449997,129.5,133.0,132.169998,128.789993,130.419998,128.460007,129.089996,129.360001,128.539993,126.410004,126.599998,127.139999,124.510002,122.239998,124.449997,123.589996,124.949997,127.040001,128.470001,127.5,125.900002,127.209999,126.690002,123.379997,124.239998,123.25,126.370003,124.43,124.25,125.32,127.349998,126.010002,125.599998,126.559998,127.099998,126.849998,126.300003,126.779999,126.169998,124.75,127.599998,126.9100
# ...
